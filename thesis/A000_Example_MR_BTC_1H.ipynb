# %% [markdown]
# # Thesis: A000 - Example Mean Reversion
#
# Author: Jan Jurhar <br>
#  Date: 2025-11-14 <br>
#  Alpha ID: A000 <br>

# %% [markdown]
# ### 1. The Inefficiency/idea (The "Why")
#
# What is my simple idea? "I want to follow the trend. I will buy when the short-term trend is positive and sell when it's negative."
#
# Why do I think this will work? "I will use two moving averages (a fast one and a slow one). When the fast one crosses above the slow one, it shows momentum is building, and a new uptrend might be starting."
#
# What am I trading? "BTC-PERP"

# %% [markdown]
# ### 2. The Rules (The "What")
#
# When do I enter (Buy)?
#
# Rule 1: "The 50-period MA crosses above the 200-period MA."
#
# When do I exit (Sell)?
#
# Rule 1: "The 50-period MA crosses below the 200-period MA."
#
# (Note: This is a "stop-and-reverse" strategy. It is always in a position, either Long or Short).

# %% [markdown]
# ### 3. The Null Hypothesis (The "Enemy")
# My "Enemy" is random luck.
#
# "My test is to prove that this strategy is not just random luck. (Even though this is a very famous strategy, so it's probably not profitable anymore)."

# %% [markdown]
# ### 4. The Test (The "How")
# Data: "BTC-PERP, 1H, from 2018-01-01"
#
# Fees: "0.04% per trade"
#
# Slippage: "0.02% per trade"
#
# Test Type: "Walk-Forward Analysis (WFA)"
#
# WFA Settings: "12-month training, 3-month testing (out-of-sample)"
#
# Parameters to Test: "None. I will test the simple 50/200 crossover. I am not optimizing yet."
#
# How do I know if I "WIN" or "LOSE"?
#
# WIN (PASS): "Out-of-sample (OOS) Sharpe Ratio is bigger than 0.5 AND OOS profit is positive."
#
# LOSE (FAIL): "The Sharpe is below 0.5 or it loses money."

# %% [markdown]
# ### 5. R&D / Exploration
# (This is where you would put your code to plot the MAs on a chart to see if they look correct.)

# %% [markdown]
# ### 6. Config Snapshot (My Settings)
# (I'm pasting my params_v2.json contents here before I run my test.)

# %% [markdown]
# ### 7. Results (The Verdict)
